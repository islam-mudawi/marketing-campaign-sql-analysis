# %% [markdown]
# <a href="https://colab.research.google.com/github/islam-mudawi/marketing-campaign-sql-analysis/blob/main/campaign_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.cloud import bigquery
from google.colab import auth
auth.authenticate_user()
client = bigquery.Client(project='marketing-analysis-490814')

# %%
query = """
  SELECT trafficSource.source AS channel,
         COUNT(*) AS sessions
  FROM `bigquery-public-data.google_analytics_sample.ga_sessions_20170801`
  GROUP BY channel
  ORDER BY sessions DESC
"""
df = client.query(query).to_dataframe()
df
# Out:
#                      channel  sessions
# 0                   (direct)      2166
# 1                youtube.com       180
# 2       analytics.google.com        57
# 3                   Partners        52
# 4                        dfa        15
# 5                 google.com        12
# 6           sites.google.com         8
# 7               facebook.com         7
# 8                  quora.com         6
# 9             m.facebook.com         5
# 10                     baidu         5
# 11                 qiita.com         5
# 12                reddit.com         4
# 13         groups.google.com         4
# 14            l.facebook.com         3
# 15           blog.golang.org         3
# 16                       ask         2
# 17        adwords.google.com         2
# 18           mail.google.com         2
# 19                     yahoo         2
# 20           lm.facebook.com         2
# 21              sashihara.jp         1
# 22               m.baidu.com         1
# ...
